# %% [markdown]
# # CASM cal + weights diagnostics: `aug23_exact512_CAL0823N`
#
# Generated by `bf_weights_generator/make_cal_and_weights.py` (canonical recipe, see `docs/canonical-recipe.md`). Every figure is described under its own heading, with what a healthy and a sick version look like. All time axes are local time at OVRO.
#
# ## Provenance
#
# ```json
# {
#   "driver": "/home/casm/software/dev/bf_weights_generator/bf_weights_generator/make_cal_and_weights.py",
#   "cal_file": "/mnt/nvme5/vishnu/cal_build_20260824/cal_aug23_exact512_CAL0823N.h5",
#   "weights_file": "/mnt/nvme5/vishnu/cal_build_20260824/weights_aug23_exact512_CAL0823N_16ant_512_int8.h5",
#   "layout": "/home/casm/software/dev/antenna_layouts/casm_antenna_layout_2026-08-07.csv",
#   "antennas": [
#     9,
#     10,
#     15,
#     19,
#     22,
#     23,
#     24,
#     26,
#     30,
#     32,
#     36,
#     38,
#     40,
#     42,
#     44,
#     45
#   ],
#   "grid": {
#     "mode": "exact",
#     "criterion": "rate",
#     "floor_weight": 0.0,
#     "n_ant": 16,
#     "alt_min": 22.0,
#     "alt_max": 90.0,
#     "az_min": 0.0,
#     "az_max": 358.8079470198676,
#     "bounds": [
#       20.0,
#       90.0,
#       0.0,
#       360.0
#     ]
#   },
#   "report_json": "/mnt/nvme5/vishnu/cal_build_20260824/report_aug23_exact512_CAL0823N.json",
#   "numpy": "2.4.2",
#   "fixed_policy": {
#     "freq_config": "FrequencyConfig.layout_64ant()",
#     "svd": {
#       "threshold": 1.0,
#       "mode": "PHASE_ONLY",
#       "block_size": 1,
#       "masked_band_strategy": "zero"
#     },
#     "fringe_stop_sign": -1,
#     "scale_factor": 127.0,
#     "freq_order": "descending",
#     "cb_slots": 64
#   }
# }
# ```
#
# ## Parameters
#
# ```json
# {
#   "out_dir": "/mnt/nvme5/vishnu/cal_build_20260824",
#   "tag": "aug23_exact512_CAL0823N",
#   "cal_source": "sun",
#   "cal_ra": null,
#   "cal_dec": null,
#   "source_window": [
#     "2026-08-23 20:41:30",
#     "2026-08-23 21:41:30"
#   ],
#   "static_window": [
#     "2026-08-24 03:00:00",
#     "2026-08-24 03:30:00"
#   ],
#   "static_path": "/mnt/nvme5/vishnu/cal_build_20260824/static_aug23_exact512_CAL0823N.npz",
#   "static_window_tol_s": 300.0,
#   "static_notes": "night static from obs 2026-08-24-01:54:29 only. Window forced later than 02:56 UTC because 02:30-03:00 straddles three overlapping obs on disk (2026-08-23-19:18:14 ends 02:38:02, the 1105-byte stub 2026-08-24-01:42:35 advertises 01:42-02:55, and 2026-08-24-01:54:29). Altitudes: sun -11.3..-5.7, Cyg A 58.3..63.9, Cas A 30.3..33.9, Tau A -30.7. Cyg A is ~3 deg higher than the deployed Aug-20 02:45-03:15 static window (52.5..58.1).",
#   "antennas": [
#     9,
#     10,
#     15,
#     19,
#     22,
#     23,
#     24,
#     26,
#     30,
#     32,
#     36,
#     38,
#     40,
#     42,
#     44,
#     45
#   ],
#   "ref_ant": 9,
#   "layout_csv": "/home/casm/software/dev/antenna_layouts/casm_antenna_layout_2026-08-07.csv",
#   "min_alt_deg": 10.0,
#   "min_time_on_source_frac": 0.5,
#   "cal_path": null,
#   "make_weights": true,
#   "grid_mode": "exact",
#   "alt_min_deg": 20.0,
#   "alt_max_deg": 90.0,
#   "az_min_deg": 0.0,
#   "az_max_deg": 360.0,
#   "n_beams": 512,
#   "mult_min": 0.05,
#   "mult_max": 0.6,
#   "mult_n": 56,
#   "mult_break_below_target": false,
#   "trim": "lowest",
#   "exact_criterion": "rate",
#   "exact_floor_weight": 0.0,
#   "track_sources": [
#     "sun",
#     "b0329+54"
#   ],
#   "track_date": "2026-08-25",
#   "track_min_alt_deg": 0.0,
#   "track_pad_deg": 0.0,
#   "verify_pointing": true,
#   "verify_beams": [
#     0,
#     256,
#     511
#   ],
#   "min_subband_good_frac": 0.9,
#   "nearest_targets": [],
#   "nearest_sources": [
#     "sun",
#     "b0329+54"
#   ],
#   "nearest_date": "2026-08-25",
#   "prev_cal_path": "/mnt/nvme5/solar0819/cal_static_night/cal_sun_2026-08-19_thr1_phaseonly_16ant_nightstaticB.h5",
#   "diagnostics": true,
#   "notebook": true,
#   "execute_notebook": true,
#   "fringe_plot_max_baselines": 20,
#   "phase_baselines_per_class": 3,
#   "beam_check": true,
#   "beam_check_source": "cyg-a",
#   "beam_check_fallback": "cas-a",
#   "beam_check_date": "2026-08-24",
#   "beam_check_window": null,
#   "beam_check_minutes": 60.0,
#   "beam_check_off_alt_deg": -25.0,
#   "transit_sources": [
#     "sun",
#     "cyg-a",
#     "cas-a",
#     "b0329+54"
#   ],
#   "transit_date": "2026-08-25"
# }
# ```

# %%
import os
from IPython.display import Image, display
os.chdir('/mnt/nvme5/vishnu/cal_build_20260824')
print(os.getcwd())
# Out:
# /mnt/nvme5/vishnu/cal_build_20260824

# %% [markdown]
# ## Autocorrelation spectra of the active antennas
#
# Time-averaged autocorrelation power per antenna over the same visibilities the cal was solved on.
#
# *Healthy*: every panel shows the same smooth bandpass shape at a similar level, with the known narrow RFI lines. *Sick*: a flat/featureless panel (dead feed), one sitting 12+ dB above the rest (railed ADC), or a whole 512-channel block at the floor (missing subband).

# %%
for p in ['figs/autocorr_aug23_exact512_CAL0823N.png']:
    if os.path.exists(p):
        display(Image(filename=p))
    else:
        print('MISSING FIGURE:', p)

# %% [markdown]
# ## Raw cross-correlation phase vs frequency (the delay sawtooth)
#
# Time-averaged raw phase for short, medium and long reference-antenna baselines, ordered by baseline length. First figure is wrapped phase (the sawtooth), second is unwrapped.
#
# *Healthy*: a clean linear ramp, wrapping many times across the band - that slope is the geometric delay plus the antenna's cable delay, so it grows with baseline length only roughly. *Sick*: phase noise with no ramp (no fringes on that baseline) or jumps at subband edges.

# %%
for p in ['figs/phase_raw_sawtooth_aug23_exact512_CAL0823N.png', 'figs/phase_stage1_raw_aug23_exact512_CAL0823N.png']:
    if os.path.exists(p):
        display(Image(filename=p))
    else:
        print('MISSING FIGURE:', p)

# %% [markdown]
# ## The same baselines after fringe-stopping
#
# Geometric delay toward the calibrator removed (`sign=-1`); only instrumental phase is left.
#
# *Healthy*: the fast ramp is gone, leaving slow structure - a residual cable delay of a few ns plus bandpass ripple. *Sick*: the ramp survives (wrong source or wrong antenna positions).

# %%
for p in ['figs/phase_stage2_fringe_stopped_aug23_exact512_CAL0823N.png']:
    if os.path.exists(p):
        display(Image(filename=p))
    else:
        print('MISSING FIGURE:', p)

# %% [markdown]
# ## After fringe-stopping AND the solved cal
#
# The same baselines with the per-antenna solution divided out: `V_ij conj(g_i) g_j`. Plotted wrapped, not unwrapped.
#
# *Healthy*: flat at zero across the band on every baseline. *Sick*: any surviving slope (the delay the solve failed to absorb) or a band where the residual scatters over the full +/-pi.

# %%
for p in ['figs/phase_stage3_calibrated_aug23_exact512_CAL0823N.png']:
    if os.path.exists(p):
        display(Image(filename=p))
    else:
        print('MISSING FIGURE:', p)

# %% [markdown]
# ## Per-antenna solved gain phase with the fitted delay
#
# Blue: the solved gain phase referenced to antenna 9. Red: the best-fit pure delay (+/-300 ns brute-force search, `run_cal_diff.py`). Panel titles carry the delay and the residual rms. Table: `gain_delay_fits_aug23_exact512_CAL0823N.csv`.
#
# *Healthy*: the red line tracks the blue points across the whole band with residual rms well under ~0.5 rad. *Sick*: a large residual (structure a delay cannot describe) or a delay jumping by an ADC-sample multiple vs the last cal.

# %%
for p in ['figs/gain_delay_fits_aug23_exact512_CAL0823N.png']:
    if os.path.exists(p):
        display(Image(filename=p))
    else:
        print('MISSING FIGURE:', p)

# %% [markdown]
# ## Rank-1 ratio vs frequency
#
# Per-channel sigma_1/sigma_2 of the fringe-stopped visibility matrix (phase-only SVD). Dashed line at 1.0, dotted at the primary median.
#
# *Healthy*: well above 1 across the band - the source dominates and the channel is trustworthy. *Sick*: hugging 1.0, or collapsing over a whole subband.

# %%
for p in ['figs/rank1_vs_freq_aug23_exact512_CAL0823N.png']:
    if os.path.exists(p):
        display(Image(filename=p))
    else:
        print('MISSING FIGURE:', p)

# %% [markdown]
# ## SVD singular values vs frequency
#
# sigma_1..6 of the per-channel phase-only solve matrix (left, log scale) and the rank-1 fraction sigma_1/sum(sigma) (right), the `svd_census/svd_vs_freq` view. The entries are unit-modulus with a zeroed diagonal, so a perfectly coherent point source gives sigma_1 = N-1 and a rank-1 fraction of 0.5, not 1.
#
# *Healthy*: sigma_1 pinned near N-1, far above sigma_2..k, and the fraction near 0.5 in band. *Sick*: the singular values bunch together and the fraction falls toward the incoherent floor 1/N.

# %%
for p in ['figs/svd_vs_freq_aug23_exact512_CAL0823N.png']:
    if os.path.exists(p):
        display(Image(filename=p))
    else:
        print('MISSING FIGURE:', p)

# %% [markdown]
# ## Fringe-stopped visibility waterfalls
#
# Per SNAP pair: raw phase, the geometric model, and the fringe-stopped residual, against local time.
#
# *Healthy*: raw and model show the same fringe pattern and the residual is vertically banded (constant in time). *Sick*: residual fringes still sloping in time (bad positions/source) or a baseline that is pure speckle (dead antenna).

# %%
for p in ['figs/fringe_aug23_exact512_CAL0823N/fringe_diag_snap0_to_0.png', 'figs/fringe_aug23_exact512_CAL0823N/fringe_diag_snap0_to_1.png', 'figs/fringe_aug23_exact512_CAL0823N/fringe_diag_snap0_to_2.png', 'figs/fringe_aug23_exact512_CAL0823N/fringe_diag_snap0_to_3.png']:
    if os.path.exists(p):
        display(Image(filename=p))
    else:
        print('MISSING FIGURE:', p)

# %% [markdown]
# ## Static A/B
#
# In-band rank-1 median with the static subtracted: 9.054; without: 5.822. Full band: 5.873 vs 4.097.
#
# *Healthy*: subtracting the static raises the in-band rank-1 median. If it lowers it, the static window was not quiet.

# %% [markdown]
# ## Per-antenna phase and delay diff vs the previous cal
#
# New cal minus `/mnt/nvme5/solar0819/cal_static_night/cal_sun_2026-08-19_thr1_phaseonly_16ant_nightstaticB.h5`, referenced to antenna 9. Band-averaged predicted coherent beam power if the OLD cal were kept: 0.991. Table: `cal_diff_aug23_exact512_CAL0823N.csv`.
#
# *Healthy*: differences flat and small; predicted coherence near 1 means nothing moved. *Sick*: clean delay slopes per antenna (something re-cabled or an ADC slipped) - deploying the new cal is then necessary, not optional.

# %%
for p in ['figs/cal_diff_aug23_exact512_CAL0823N.png']:
    if os.path.exists(p):
        display(Image(filename=p))
    else:
        print('MISSING FIGURE:', p)

# %% [markdown]
# ## Beamformed response on cyg-a
#
# Coherent beam steered at cyg-a through the available span with the just-solved cal, in the visibility domain (`P = 2 Re sum_ij w_i w_j* V_ij`, normalised by `2 sum |V_ij|` so 1.0 is a perfectly phased point source). Window 2026-08-24 05:13:00 - 2026-08-24 06:13:00 UTC, 26 integrations, altitude 83.2-86.4 deg. Band-averaged: new cal = +0.0646; previous cal = +0.0674; null: -25 deg off = +0.0175.
#
# *Healthy*: the new cal is clearly above zero and beats both the off-source null and the previous cal. *Sick*: on-source sitting at the null level - the cal does not phase the array on an independent source. Caveat: the null is a rough control, not a zero - an altitude-offset beam can still land on real sky structure, so read it as a scale, not as a floor.

# %%
for p in ['figs/beam_check_cyga_aug23_exact512_CAL0823N.png']:
    if os.path.exists(p):
        display(Image(filename=p))
    else:
        print('MISSING FIGURE:', p)

# %% [markdown]
# ## Beam grid
#
# Alt/az of every beam, coloured by beam index; red stars are the nearest-beam targets.
#
# *Healthy*: the targets sit inside the beam cloud, well under a beam FWHM from the nearest beam. *Sick*: a target outside the grid, or a visible hole in the coverage.

# %%
for p in ['figs/beam_grid_aug23_exact512_CAL0823N.png']:
    if os.path.exists(p):
        display(Image(filename=p))
    else:
        print('MISSING FIGURE:', p)

# %% [markdown]
# ## Source-transit coverage of the new grid
#
# `bf_weights_generator.plot_source_transit` (the same machinery as `casm-bf-source-transit`) for sun, cyg-a, cas-a, b0329+54 on 2026-08-25, local time.
#
# *Healthy*: each source of interest passes through beams for a usable stretch of the day. *Sick*: a source that never enters a beam - the grid is pointed somewhere else.

# %%
for p in ['figs/source_transit_aug23_exact512_CAL0823N.png']:
    if os.path.exists(p):
        display(Image(filename=p))
    else:
        print('MISSING FIGURE:', p)
